# %%
def f():
    print("Hello")
def f():
    print("Hi")
f()
# Out:
# Hi

# %%
a,b=5,7
if a>6:
    print("V")
elif b>5:
    print("LJIET")
if a>4:
    print("LJIET10")
elif b>6:
    print("10LJIET")
if a==5 and b==7:
    print("TAT")
else:
    print(i)
# Out:
# LJIET
# LJIET10
# TAT

# %%
a=5
if a>4:
    print("HI")
a+=8 #it throws syntax error because we cannot write anything which is not intended to if in between if and elif 
elif a>6:
    print("hello")
# Out:
#   Cell In[4], line 5
#     elif a>6:
#     ^
# SyntaxError: invalid syntax

# %%
def pr(x):
    global v
    msg=str(v)
    print(type(v))
    v="hi"
    print(v)
global v
v=6
pr("u")
# Out:
# <class 'int'>
# hi

# %%
sum=0
count=0
while count>15:
    sum+=3
    if sum==3:
        count+=5
    else:
        count+=9
else:
    count+=2
print(sum,count)
# Out:
# 0 2

# %%
sum=0
count=0
while count<15:
    sum+=3
    if sum==3:
        count+=5
    else:
        count+=9
else:
    count+=2
print(sum,count)
# Out:
# 9 25

# %%
x=0
while x<15:
    if x%3==0:
        x+=5
        continue
    if x%2==0:
        x+=14
    else:
        x+=1
else:
    x+=1
print(x)
# Out:
# 18

# %%
sum=0
for i in range(1,15):
    if i%4==0:
        sum+=3
        continue
    i+=5
    if i%3==0:
        sum+=7
        continue
    else:
        sum+=2
    sum+=3
else:
    sum+=3
print(sum)
# Out:
# 75

# %%
year=int(input("Enter a year:")) #9 marks program of practical
leap_year= False
if (year%4==0) and (year%100!=0 or year%400==0):
    leap_year = True
month=int(input("Enter a month:"))
if month in (1,3,5,7,8,10,12):
    length=31
elif month==2:
    if leap_year:
        length=29
    else:
        length=28
else:
    length=30
day=int(input("Enter Day[1-31]:"))
print(f"Current date:{year}-{month}-{day}")
if day>length:
    print("Enter Valid day")
else:
    if day<length:
        day+=1
        print(f"Next date:{year}-{month}-{day}")
    else:
        day=1
        if month==12:
            month=1
            year+=1
        else:
            month+=1
        print(f"Next Date:{year}-{month}-{day}")
# Out:
# Enter a year: 2000
# Enter a month: 12
# Enter Day[1-31]: 3
# Current date:2000-12-3
# Next date:2000-12-4

# %%
#harshad number= e.g.: 156=1+5+6=12 156%12==0 ,  then it is harshad number
x=int(input("Enter number:"))
def harshad(x):
    temp=x
    sum=0
    while x!=0:
        d=x%10
        sum=sum+d
        x=x//10
    if temp%sum==0:
        print("It is a harshad number")
    else:
        print("IT is not a harshad number")
harshad(x)
# Out:
# Enter number: 23
# IT is not a harshad number

# %% [markdown]
# n(n+1) = Chronic numbers
#
# 1(1+1)=2
# 2(2+1)=6 till 9(9+1)=90

# %%
for i in range(1,101):
    for j in range(1,i+1):
        if(j*(j+1)==i):
            print(i,end=" ")
            break
# Out:
# 2 6 12 20 30 42 56 72 90

# %% [markdown]
# **Gross Pay**
#
# Annual Income
#
# Tax Calculation
#
# GP= Basic Pay
#
#     HRA
#
#     DA
#
#     Other Allowances and Transport Allowances
#
#     PF
#
#     Prof Tax
#
# GP = Basic Pay + HRA + DA + Other A + Trans A - Prof tax - PF

# %%
grade = input("Enter Grade:")
city=int(input("Enter city class:"))
TA=900
p_tax=200
if grade=="A" or "a" and city==1:
    basic_pay=60000
    other_allowance=8000
    HRA=basic_pay*0.3
    DA=basic_pay*0.5
    Prof_tax=basic_pay*0.11
    print(gp)
elif grade=="A" or "a" and city==2:
    basic_pay=50000
    other_allowance=7000
    HRA=basic_pay*0.3
    DA=basic_pay*0.5
    Prof_tax=basic_pay*0.11
    print(gp)
